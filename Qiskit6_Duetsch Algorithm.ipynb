# %%
import qiskit
import numpy as np
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import Aer
from qiskit import transpile
from qiskit.visualization import circuit_drawer, plot_bloch_multivector, plot_histogram
from qiskit.visualization import array_to_latex
from qiskit.quantum_info import random_statevector
#from qiskit.extensions import initialize
from math import pi, sqrt
import pylatexenc
from pylatexenc.latex2text import LatexNodes2Text

# %%
qc = QuantumCircuit(2, 1, name = "qc")

qc.x(1) # flip the second qubit
qc.barrier()

qc.h(0)
qc.h(1)
qc.barrier()

# this part is our Oracle
qc.id(0) # identitiy gate
qc.id(1)
qc.barrier()

qc.h(0)
qc.barrier()

qc.measure(0,0) # only measure the first qubit

qc.draw('mpl')

# %%
backend = Aer.get_backend('qasm_simulator')

duetsch = transpile (qc,backend)

job = backend.run(duetsch, shots = 1000)


result = job.result()

counts = result.get_counts(qc)

print("\n Total counts are: ", counts)

plot_histogram(counts)
# Out:
#  Total counts are:  {'0': 1000}

# %%
qc = QuantumCircuit(2, 1, name = "qc")

qc.x(1) # flip the second qubit
qc.barrier()

qc.h(0)
qc.h(1)
qc.barrier()

# change the oracle to see different results
qc.id(0) # identitiy gate
qc.x(1)
qc.barrier()

qc.h(0)
qc.barrier()

qc.measure(0,0) # only measure the first qubit

qc.draw('mpl')

# %%
backend = Aer.get_backend('qasm_simulator')

duetsch = transpile (qc,backend)

job = backend.run(duetsch, shots = 1000)


result = job.result()

counts = result.get_counts(qc)

print("\n Total counts are: ", counts)

plot_histogram(counts)
# Out:
#  Total counts are:  {'0': 1000}

# %%
qc = QuantumCircuit(2, 1, name = "qc")

qc.x(1) # flip the second qubit
qc.barrier()

qc.h(0)
qc.h(1)
qc.barrier()

qc.cx(0,1)
qc.barrier()

qc.h(0)
qc.barrier()

qc.measure(0,0) # only measure the first qubit

qc.draw('mpl')

# %%
backend = Aer.get_backend('qasm_simulator')

duetsch = transpile (qc,backend)

job = backend.run(duetsch, shots = 1000)


result = job.result()

counts = result.get_counts(qc)

print("\n Total counts are: ", counts)

plot_histogram(counts)
# Out:
#  Total counts are:  {'1': 1000}

# %%
qc = QuantumCircuit(2, 1, name = "qc")

qc.x(1) # flip the second qubit
qc.barrier()

qc.h(0)
qc.h(1)
qc.barrier()

qc.cx(0,1)
qc.x(1)
qc.barrier()

qc.h(0)
qc.barrier()

qc.measure(0,0) # only measure the first qubit

qc.draw('mpl')

# %%
backend = Aer.get_backend('qasm_simulator')

duetsch = transpile (qc,backend)

job = backend.run(duetsch, shots = 1000)


result = job.result()

counts = result.get_counts(qc)

print("\n Total counts are: ", counts)

plot_histogram(counts)
# Out:
#  Total counts are:  {'1': 1000}
